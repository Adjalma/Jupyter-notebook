# %% [markdown]
# <a href="https://colab.research.google.com/github/Adjalma/Jupyter-notebook/blob/main/C%C3%B3pia_de_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Adjalma MAchado Aguiar Junior RID = 98622

# %%
nomes = ["Tibério", "Renato", "Paulo", "Julio", "Carlos", "Lauro", "Jeferson", "Flávio", "Adjalma", "Adriano", "Michel", "Denes"]
idades = [34, 29, 29, 26, 41, 26, 27, 26, 37, 28, 41, 47]
salarios = [20000, 30000, 25000, 100000, 20000, 15000, 15000, 25000, 20000, 15000 ,25000]

# %%
nome_idade = []
for nome, idade in zip(nomes, idades):
  nome_idade.append([nome, idade])

header = ['Nome', 'Idade']
nome_idade.insert(0, header)
print(nome_idade)
# Out:
# [['Nome', 'Idade'], ['Tibério', 34], ['Renato', 29], ['Paulo', 29], ['Julio', 26], ['Carlos', 41], ['Lauro', 26], ['Jeferson', 27], ['Flávio', 26], ['Adjalma', 37], ['Adriano', 28], ['Michel', 41], ['Denes', 47]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (18,10))
plt.bar(nome, idade)
# Out:
# <BarContainer object of 1 artists>
